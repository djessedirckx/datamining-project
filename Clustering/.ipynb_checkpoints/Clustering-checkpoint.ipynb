# %%
import pandas as pd
training_data = "../Data/training_binary.csv"
data = pd.read_csv(training_data)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.cluster
from Toolbox.clusterPlot import clusterPlot
X_data = data.drop(['cuisine', 'id'],axis=1)
y_data = data['cuisine']
kmeans = sklearn.cluster.KMeans(n_clusters = 4).fit(X_data)
ClustX = kmeans.labels_
Centroids = kmeans.cluster_centers_
plt.figure()
clusterPlot(X_data, ClustX,Centroids,y_data)
plt.title('Clustering of synth1 data')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
