# %%
import pandas as pd
import numpy as np
import time

# Read training data
training_file_path = "../Data/train.json"
data = pd.read_json(training_file_path, orient='columns')

# Extract X (ingredients) and y (cuisine)
X = data['ingredients']
y = data['cuisine']

# %%
# Create a unique set of ingredients
ingredient_set = set()
for ingredients in X:
    for ingredient in ingredients:
        ingredient_set.add(ingredient)
        
# Convert set to list to create indexes
ingredients_list = list(ingredient_set)
ingredients_list
# Out:
# ['evaporated low-fat 2% milk',
#  'sandwich wraps',
#  'jam',
#  'gran marnier',
#  'whole wheat lasagna noodles',
#  'red anjou pears',
#  'shao hsing wine',
#  'whole wheat pasta shells',
#  'pickled garlic',
#  'string cheese',
#  'less sodium beef broth',
#  'sushi vinegar',
#  'ground Italian sausage',
#  'phyllo dough',
#  'Lipton Sparkling Diet Green Tea with Strawberry Kiwi',
#  'shredded monterey jack cheese',
#  'Tapatio Hot Sauce',
#  'raw honey',
#  'pink grapefruit',
#  'chestnuts',
#  'Balsamico Bianco',
#  'all purpose seasoning',
#  'whole wheat tortilla wraps',
#  'oyster liquor',
#  'whole wheat pita rounds',
#  'mint sprigs',
#  'pecan meal',
#  'topside steak',
#  'chocolate candy',
#  'fresh cheese',
#  'thai green curry paste',
#  'knorr homestyl stock   beef',
#  'muffin',
#  'fine grind white cornmeal',
#  'pork butt',
#  'daal',
#  'beaten eggs',
#  'minced beef',
#  'reduced-fat sour cream',
#  'fenugreek seeds',
#  'mustard',
#  'chilled prosecco',
# ...

# %%
# Create a unique set of cuisines
cuisine_set = set()
for cuisine in y:
    cuisine_set.add(cuisine)
    
# Convert set to list to create indexes
cuisine_list = list(cuisine_set)

# %%
# Add a column for every ingredient to the dataframe
i = 0
start = time.time()
for ingredient in ingredients_list[2:10]:
    i = i + 1
    
    if i % 1000 ==0:
        print(i)
    scores = []
    
    # Check whether recipe contains ingredient or not
    for rec_ing in data['ingredients']:
        if ingredient in rec_ing:
            scores.append(1)
        else:
            scores.append(0)
    
    data[ingredient] = scores
end = time.time()

print('Execution time: {}'.format(end - start))
# Out:
# Execution time: 0.2482280731201172

# %%
for col in data.columns:
    print(col)
# Out:
# cuisine
# id
# ingredients
# evaporated low-fat 2% milk
# sandwich wraps
# jam
# gran marnier
# whole wheat lasagna noodles
# red anjou pears
# shao hsing wine
# whole wheat pasta shells
# pickled garlic
# string cheese

# %%
# Drop ingredients column
data = data.drop(['ingredients'],axis=1)

# %%
# Write file to json
data.to_json(r'training_binary.json')
new_data = pd.read_json('training_binary.json', orient='columns').head(1000)
# Out:
#           cuisine     id  cinnamon  fresh mint  plum sauce  \
# 0           greek  10259         0           0           0
# 1     southern_us  25693         0           0           0
# 10        italian   5875         0           0           0
# 100       italian  17636         0           0           0
# 101      japanese   8997         0           0           0
# 102       italian  28851         0           0           0
# 103         greek   4635         0           0           0
# 104        korean   7782         0           0           0
# 105        indian   8031         0           0           0
# 106       mexican  49434         0           0           0
# 107   southern_us  31318         0           0           0
# 108         irish  31027         0           0           0
# 109        korean  47095         0           0           0
# 11        chinese  45887         0           0           0
# 110       chinese   4574         0           0           0
# ...
